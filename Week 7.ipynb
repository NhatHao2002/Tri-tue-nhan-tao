# %% [markdown]
# <a href="https://colab.research.google.com/github/NhatHao2002/Tri-tue-nhan-tao/blob/main/Week%207.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url='mtcars.csv'
data=pd.read_csv(url)
data.head()
# Out:
#           Unnamed: 0   mpg   disp   hp     wt
# 0          Mazda RX4  21.0  160.0  110  2.620
# 1      Mazda RX4 Wag  21.0  160.0  110  2.875
# 2         Datsun 710  22.8  108.0   93  2.320
# 3     Hornet 4 Drive  21.4  258.0  110  3.215
# 4  Hornet Sportabout  18.7  360.0  175  3.440

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data.hist()
plt.show()

# %%
correlation = data.corr()
print(correlation)
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000

# %%
sns.pairplot(data)

# %%
sns.heatmap(correlation,annot=True)

# %%
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='wt', ylabel='mpg'>

# %%
from sklearn import linear_model
model =linear_model.LinearRegression()
X = pd.DataFrame(data['wt'])
y=data['mpg']
model.fit(X,y)
print('Gia tri Intercept la:', model.intercept_)
print('Gia tri Coeffient la:', model.coef_)
model.score(X,y)
# Out:
# Gia tri Intercept la: 37.28512616734204
# Gia tri Coeffient la: [-5.34447157]
# 0.7528327936582646

# %%
from sklearn import linear_model
model =linear_model.LinearRegression()
X = data.loc[:,['wt','hp']]
y=data['mpg']
model.fit(X,y)
print('He so Intercept la:', model.intercept_)
print('He so Coeffient la:', model.coef_)
print('Do chinh xac cua mo hinh la:', model.score(X,y))
# Out:
# He so Intercept la: 37.227270116447215
# He so Coeffient la: [-3.87783074 -0.03177295]
# Do chinh xac cua mo hinh la: 0.8267854518827914

# %%
from sklearn import linear_model
model =linear_model.LinearRegression()
X = data.loc[:,['wt','hp','disp']]
y=data['mpg']
model.fit(X,y)
print('He so Intercept la:', model.intercept_)
print('He so Coeffient la:', model.coef_)
print('Do chinh xac cua mo hinh la:', model.score(X,y))
# Out:
# He so Intercept la: 37.10550526903184
# He so Coeffient la: [-3.80089058e+00 -3.11565508e-02 -9.37009081e-04]
# Do chinh xac cua mo hinh la: 0.8268361424946447

# %%
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black')
y_pred=model.predict(X)
plt.plot(data['wt'],y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model=linear_model.LinearRegression()
X=pd.DataFrame([data['wt'],data['wt']**2]).T
y=data['mpg']
model.fit(X,y)
print('He so Intercept la:', model.intercept_)
print('He so coneffient la:', model.coef_)
print('Do chinh xac cua mo hinh la:', model.score(X,y))
# Out:
# He so Intercept la: 49.93081094945181
# He so coneffient la: [-13.38033708   1.17108689]
# Do chinh xac cua mo hinh la: 0.8190613581384094

# %%
import numpy as np
range=np.arange(1.5,5.5,0.1)
X_range=pd.DataFrame([range, range**2]).T
y_pred = model.predict(X_range)
data.plot(kind='scatter', x='wt', y='mpg', figsize=(9,9), color='black', xlim=(0,7))
plt.plot(range, y_pred, color='blue')

# %%
import numpy as np
range=np.arange(2.3,6.5,0.1)
X_range=pd.DataFrame([range,range**3]).T
y_pred=model.predict(X_range)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')

# %%
import pandas as pd
url='50_Startups.csv'
data1 = pd.read_csv(url)
data1.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data1.hist()
plt.show()

# %%
correlation1 = data1.corr()
print(correlation1)
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
sns.pairplot(data1)

# %%
sns.heatmap(correlation1, annot = True)
# Out:
# <Axes: >

# %%
data1.plot(kind='scatter', x='R&D Spend', y='Profit', figsize=(9,9), color='black')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='R&D Spend', ylabel='Profit'>

# %%
from sklearn import linear_model
model1 =linear_model.LinearRegression()
X1 = pd.DataFrame(data1['R&D Spend'])
y1=data1['Profit']
model.fit(X1,y1)
print('Gia tri Intercept la:', model.intercept_)
print('Gia tri Coeffient la:', model.coef_)
model.score(X1,y1)
# Out:
# Gia tri Intercept la: 49032.89914125215
# Gia tri Coeffient la: [0.85429137]
# 0.9465353160804393

# %%
data1.plot(kind='scatter', x='R&D Spend', y='Profit', figsize=(9,9), color='black')
y_pred1 = model.predict(X1)
plt.plot(data1['R&D Spend'], y_pred1, color = 'blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model1=linear_model.LinearRegression()
X1=pd.DataFrame([data1['R&D Spend'], data1['R&D Spend']**2]).T
y1=data1['Profit']
model.fit(X1,y1)
print('He so Intercept la:', model.intercept_)
print('He so coneffient la:', model.coef_)
print('Do chinh xac cua mo hinh la:', model.score(X1,y1))
# Out:
# He so Intercept la: 48128.14916956878
# He so coneffient la: [ 8.90147291e-01 -2.31821806e-07]
# Do chinh xac cua mo hinh la: 0.946703652909133

# %%
import pandas as pd
url3='/content/Advertising.csv'
data3=pd.read_csv(url3)
data3.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data3.hist()
plt.show()

# %%
correlation3 = data3.corr()
print(correlation3)
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
sns.pairplot(data3)

# %%
sns.heatmap(correlation3,annot=True)

# %%
data3.plot(kind='scatter', x='TV', y='sales', figsize=(9,9), color = 'black')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='TV', ylabel='sales'>

# %%
from sklearn import linear_model
model3 =linear_model.LinearRegression()
X3 = pd.DataFrame(data3['radio'])
y3 = data3['sales']
model.fit(X3,y3)
print('Gia tri Intercept la:', model.intercept_)
print('Gia tri Coeffient la:', model.coef_)
print('Do chinh xac cua mo hinh la:', model.score(X3,y3))
# Out:
# Gia tri Intercept la: 9.311638095158283
# Gia tri Coeffient la: [0.20249578]
# Do chinh xac cua mo hinh la: 0.33203245544529525

# %%
from sklearn import linear_model
model3 = linear_model.LinearRegression()
X3 = pd.DataFrame(data3['newspaper'])
y3 = data3['sales']
model.fit(X3,y3)
print('Gia tri Intercept la:', model.intercept_)
print('Gia tri Coeffient la:', model.coef_)
print('Do chinh xac cua mo hinh la:', model.score(X3,y3))
# Out:
# Gia tri Intercept la: 12.35140706927816
# Gia tri Coeffient la: [0.0546931]
# Do chinh xac cua mo hinh la: 0.05212044544430516

# %%
model3 = linear_model.LinearRegression()
X3 = pd.DataFrame([data3['TV'],data3['TV']**2]).T
y3 = data3['sales']
model.fit(X3,y3)
print('He so Intercept la:', model.intercept_)
print('He so coneffient la:', model.coef_)
print('Do chinh xac cua mo hinh la:', model.score(X3,y3))
# Out:
# He so Intercept la: 6.1141201283331075
# He so coneffient la: [ 6.72659270e-02 -6.84693373e-05]
# Do chinh xac cua mo hinh la: 0.6190371168872755

# %%
model3 = linear_model.LinearRegression()
X3 = pd.DataFrame([data3['TV'],data3['TV']**2,data3['TV']**3]).T
y3 = data3['sales']
model.fit(X3,y3)
print('He so Intercept la:', model.intercept_)
print('He so coneffient la:', model.coef_)
print('Do chinh xac cua mo hinh la:', model.score(X3,y3))
# Out:
# He so Intercept la: 5.420106548191448
# He so coneffient la: [ 9.64341770e-02 -3.15222433e-04  5.57199796e-07]
# Do chinh xac cua mo hinh la: 0.6220016830036417
